# %%
import numpy as np
import pandas as pd 
import os

dfs = []
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        path = os.path.join(dirname, filename)
        df = pd.read_csv(path)
        dfs.append(df)

# %%
# import data
rating = dfs[0]
rating.head()
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
# make the user ids go from 0...(n-1)

rating['userId'] = rating['userId'] - 1

# %%
# create a mapping for movie ids
# {'movie_id':0, 'movie_id':1}

len(rating['movieId'].values) # 20000263

unique_movie_ids = set(rating['movieId'].values)

movie_idx = {}
start = 0
for unique_movie_id in unique_movie_ids:
    movie_idx[unique_movie_id] = start
    start += 1

# %%
# rating = rating.append(movie_idx, ignore_index=True)

rating.apply(lambda x: movie_idx[x['movieId']], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_971/394453372.py in <module>
#       1 # rating = rating.append(movie_idx, ignore_index=True)
#       2
# ----> 3 rating.apply(lambda x: movie_idx[x['movieId']], axis=1)
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwargs)
#    8738             kwargs=kwargs,
#    8739         )
# -> 8740         return op.apply()
#    8741
#    8742     def applymap(
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in apply(self)
#     686             return self.apply_raw()
#     687
# --> 688         return self.apply_standard()
#     689
#     690     def agg(self):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/apply.py in apply_standard(self)
#     810
#     811     def apply_standard(self):
# ...

# %%
rating = rating.drop(columns = ['timestamp'])
rating.to_csv('')

# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from datetime import datetime
from sortedcontainers import SortedList
